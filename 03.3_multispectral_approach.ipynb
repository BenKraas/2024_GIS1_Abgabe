# %%
# imports
from pathlib import Path
import rasterio
import re
import pandas as pd
import numpy as np
import json

# %%
# Author: Ben Kraas
# Some help from copilot was used to write this code

root = Path("")

# terrible, terrible hardcoded dictionary to map the index to the year and month but it does make it robust and easy for me
manual_match = {"1": "2020_1", "2": "2020_2", "3": "2020_3", "4": "2020_4",\
				"5": "2021_1", "6": "2021_2", "7": "2021_3", "8": "2021_4",\
				"9": "2022_1", "10": "2022_2", "11": "2022_3", "12": "2022_4",\
				"13": "2023_1", "14": "2023_2", "15": "2023_3", "16": "2023_4",\
				"17": "2024_1", "18": "2024_2", "19": "2024_3", "20": "2024_4"}
index_to_month_lut = {"1": "spring", "2": "summer", "3": "autumn", "4": "winter"}
year_mult_lut = {"2020": 1, "2021": 2, "2022": 3, "2023": 4, "2024": 5}

# Iterate over Sentinel 2 tifs in the data/source/sentinel2 directory and load all 13 bands from each single file
data_dict = {}

had_warning = False
for file in root.glob("data/source/sentinel-2-means-100m-tif/*.tif"):
	print(f"Processing file: {file.name}")
	# Match the file name to the manual_match dictionary
	match = re.search(r".*(\d{4})_(\d).*", file.name)
	if match:
		year = match.group(1)
		index = match.group(2)
		findstring = f"{year}_{index}"
		if findstring in manual_match.values():
			final_name = f"S2_{year}_{index}_{index_to_month_lut[index]}.tif"
			print(f"  Found match: {final_name}")
			# Get the year and month from the file name
		else:
			print(f"  WARNING: No match found for {file.name}")
			continue

		raster_dict = {}
		position = int(index) * int(year_mult_lut[year])
		print(f"  Opening file: {file.name} at position {position}")

		with rasterio.open(file) as src:
			# Read all bands into a 2D numpy array
			bands = src.read()
			print(f"  File: {file.name}")
			print(f"  Number of bands: {src.count}")

			# get metadata outlining the band names
			band_names = src.descriptions
			# print(f"  Band names: {band_names}")

			# drop the eleventh band IF at index 11 of bandnames is "B10"
			if band_names[10] == "B10":
				bandsbefore = bands[:10, :, :]
				bandsafter = bands[11:, :, :]
				# merge the two arrays 
				bands = np.concatenate((bandsbefore, bandsafter), axis=0)
				had_warning = True
				print(f"  CAUTION: Dropping band 11 from {file.name} because it is B10")

			# Print the shape of the bands array
			print(f"  {file.name}: {bands.shape}")

			# Get the metadata of the raster
			meta = src.meta

			# assert number of bands matches the number of band names
			assert bands.shape[0] == len(band_names), f"  Number of bands {bands.shape[0]} does not match number of band names {len(band_names)}"

			# input the bands into the dictionary
			data_dict[position] = {
				"bands": bands,
				"band_names": band_names,
				"meta": meta,
				"file_name": file.name,
			}

# sort the dictionary by the keys
sorted_data_dict = dict(sorted(data_dict.items()))
# Out:
# Processing file: S2_2021_3_autumn.tif
#   Found match: S2_2021_3_autumn.tif
#   Opening file: S2_2021_3_autumn.tif at position 6
#   File: S2_2021_3_autumn.tif
#   Number of bands: 26
# S2_2021_3_autumn.tif: (26, 906, 1614)
# Processing file: S2_2020_2_summer.tif
#   Found match: S2_2020_2_summer.tif
#   Opening file: S2_2020_2_summer.tif at position 2
#   File: S2_2020_2_summer.tif
#   Number of bands: 26
# S2_2020_2_summer.tif: (26, 906, 1614)
# Processing file: S2_2024_4_winter.tif
#   Found match: S2_2024_4_winter.tif
#   Opening file: S2_2024_4_winter.tif at position 20
#   File: S2_2024_4_winter.tif
#   Number of bands: 26
# S2_2024_4_winter.tif: (26, 906, 1614)
# Processing file: S2_2022_2_summer.tif
#   Found match: S2_2022_2_summer.tif
#   Opening file: S2_2022_2_summer.tif at position 6
#   File: S2_2022_2_summer.tif
#   Number of bands: 26
# S2_2022_2_summer.tif: (26, 906, 1614)
# Processing file: S2_2022_3_autumn.tif
#   Found match: S2_2022_3_autumn.tif
#   Opening file: S2_2022_3_autumn.tif at position 9
#   File: S2_2022_3_autumn.tif
#   Number of bands: 26
# S2_2022_3_autumn.tif: (26, 906, 1614)
# Processing file: S2_2020_4_winter.tif
#   Found match: S2_2020_4_winter.tif
#   Opening file: S2_2020_4_winter.tif at position 4
#   File: S2_2020_4_winter.tif
#   Number of bands: 26
# S2_2020_4_winter.tif: (26, 906, 1614)
# Processing file: S2_2020_1_spring.tif
#   Found match: S2_2020_1_spring.tif
#   Opening file: S2_2020_1_spring.tif at position 1
#   File: S2_2020_1_spring.tif
#   Number of bands: 26
# S2_2020_1_spring.tif: (26, 906, 1614)
# Processing file: S2_2021_2_summer.tif
#   Found match: S2_2021_2_summer.tif
#   Opening file: S2_2021_2_summer.tif at position 4
#   File: S2_2021_2_summer.tif
#   Number of bands: 26
# S2_2021_2_summer.tif: (26, 906, 1614)
# Processing file: S2_2024_1_spring.tif
#   Found match: S2_2024_1_spring.tif
#   Opening file: S2_2024_1_spring.tif at position 5
#   File: S2_2024_1_spring.tif
#   Number of bands: 26
# S2_2024_1_spring.tif: (26, 906, 1614)
# Processing file: S2_2022_4_winter.tif
#   Found match: S2_2022_4_winter.tif
#   Opening file: S2_2022_4_winter.tif at position 12
#   File: S2_2022_4_winter.tif
#   Number of bands: 26
# S2_2022_4_winter.tif: (26, 906, 1614)
# Processing file: S2_2022_1_spring.tif
#   Found match: S2_2022_1_spring.tif
#   Opening file: S2_2022_1_spring.tif at position 3
#   File: S2_2022_1_spring.tif
#   Number of bands: 26
# S2_2022_1_spring.tif: (26, 906, 1614)
# Processing file: S2_2023_2_summer.tif
#   Found match: S2_2023_2_summer.tif
#   Opening file: S2_2023_2_summer.tif at position 8
#   File: S2_2023_2_summer.tif
#   Number of bands: 26
# S2_2023_2_summer.tif: (26, 906, 1614)
# Processing file: S2_2024_3_autumn.tif
#   Found match: S2_2024_3_autumn.tif
#   Opening file: S2_2024_3_autumn.tif at position 15
#   File: S2_2024_3_autumn.tif
#   Number of bands: 26
# S2_2024_3_autumn.tif: (26, 906, 1614)
# Processing file: S2_2023_3_autumn.tif
#   Found match: S2_2023_3_autumn.tif
#   Opening file: S2_2023_3_autumn.tif at position 12
#   File: S2_2023_3_autumn.tif
#   Number of bands: 26
# S2_2023_3_autumn.tif: (26, 906, 1614)
# Processing file: S2_2024_2_summer.tif
#   Found match: S2_2024_2_summer.tif
#   Opening file: S2_2024_2_summer.tif at position 10
#   File: S2_2024_2_summer.tif
#   Number of bands: 26
# S2_2024_2_summer.tif: (26, 906, 1614)
# Processing file: S2_2023_1_spring.tif
#   Found match: S2_2023_1_spring.tif
#   Opening file: S2_2023_1_spring.tif at position 4
#   File: S2_2023_1_spring.tif
#   Number of bands: 26
# S2_2023_1_spring.tif: (26, 906, 1614)
# Processing file: S2_2023_4_winter.tif
#   Found match: S2_2023_4_winter.tif
#   Opening file: S2_2023_4_winter.tif at position 16
#   File: S2_2023_4_winter.tif
#   Number of bands: 26
# S2_2023_4_winter.tif: (26, 906, 1614)
# Processing file: S2_2021_1_spring.tif
#   Found match: S2_2021_1_spring.tif
#   Opening file: S2_2021_1_spring.tif at position 2
#   File: S2_2021_1_spring.tif
#   Number of bands: 26
# S2_2021_1_spring.tif: (26, 906, 1614)
# Processing file: S2_2020_3_autumn.tif
#   Found match: S2_2020_3_autumn.tif
#   Opening file: S2_2020_3_autumn.tif at position 3
#   File: S2_2020_3_autumn.tif
#   Number of bands: 26
# S2_2020_3_autumn.tif: (26, 906, 1614)
# Processing file: S2_2021_4_winter.tif
#   Found match: S2_2021_4_winter.tif
#   Opening file: S2_2021_4_winter.tif at position 8
#   File: S2_2021_4_winter.tif
#   Number of bands: 26
# S2_2021_4_winter.tif: (26, 906, 1614)

# %%
# get per band min and max values for the first entry in the dictionary
first_dict = data_dict[1]

for index, band_raster in enumerate(first_dict["bands"]):
    # get the min and max values for each band, ignore the nodata values
    band_min = np.nanmin(band_raster)
    band_max = np.nanmax(band_raster)
    print(f"Band {first_dict['band_names'][index]} min: {band_min}, max: {band_max}, type: {band_raster.dtype}, shape: {band_raster.shape}")
# Out:
# Band B1 min: 134.83333333333334, max: 2628.5, type: float64, shape: (906, 1614)
# Band B2 min: 148.58333333333334, max: 2830.75, type: float64, shape: (906, 1614)
# Band B3 min: 127.6, max: 3416.4166666666665, type: float64, shape: (906, 1614)
# Band B4 min: 119.91666666666667, max: 3995.1666666666665, type: float64, shape: (906, 1614)
# Band B5 min: 86.41666666666667, max: 4249.083333333333, type: float64, shape: (906, 1614)
# Band B6 min: 59.333333333333336, max: 4303.083333333333, type: float64, shape: (906, 1614)
# Band B7 min: 63.916666666666664, max: 4875.7692307692305, type: float64, shape: (906, 1614)
# Band B8 min: 66.41666666666667, max: 5210.615384615385, type: float64, shape: (906, 1614)
# Band B8A min: 55.916666666666664, max: 5046.2307692307695, type: float64, shape: (906, 1614)
# Band B9 min: 38.5, max: 5080.846153846154, type: float64, shape: (906, 1614)
# Band B11 min: 61.625, max: 5360.0, type: float64, shape: (906, 1614)
# Band B12 min: 55.0, max: 5207.333333333333, type: float64, shape: (906, 1614)
# Band AOT min: 77.35714285714286, max: 114.875, type: float64, shape: (906, 1614)
# Band WVP min: 200.8, max: 943.8461538461538, type: float64, shape: (906, 1614)
# Band SCL min: 2.0, max: 9.083333333333334, type: float64, shape: (906, 1614)
# Band TCI_R min: 13.0, max: 250.0, type: float64, shape: (906, 1614)
# Band TCI_G min: 13.6, max: 235.41666666666666, type: float64, shape: (906, 1614)
# Band TCI_B min: 15.916666666666666, max: 226.5, type: float64, shape: (906, 1614)
# Band MSK_CLDPRB min: 0.0, max: 49.2, type: float64, shape: (906, 1614)
# Band MSK_SNWPRB min: 0.0, max: 7.076923076923077, type: float64, shape: (906, 1614)
# Band QA10 min: 0.0, max: 0.0, type: float64, shape: (906, 1614)
# Band QA20 min: 0.0, max: 0.0, type: float64, shape: (906, 1614)
# Band QA60 min: 0.0, max: 438.85714285714283, type: float64, shape: (906, 1614)
# Band MSK_CLASSI_OPAQUE min: nan, max: nan, type: float64, shape: (906, 1614)
# Band MSK_CLASSI_CIRRUS min: nan, max: nan, type: float64, shape: (906, 1614)
# Band MSK_CLASSI_SNOW_ICE min: nan, max: nan, type: float64, shape: (906, 1614)
# /tmp/ipykernel_154076/1699212721.py:6: RuntimeWarning: All-NaN slice encountered
#   band_min = np.nanmin(band_raster)
# /tmp/ipykernel_154076/1699212721.py:7: RuntimeWarning: All-NaN slice encountered
#   band_max = np.nanmax(band_raster)

# %%
# Load wheat spectral map from csv (data/source/wheat_spectral_map.csv)

# Read the CSV skipping the units row (line 2, index 1)
spectral_map_lut = pd.read_csv("data/source/wheat_spectral_map.csv", skiprows=1)

# drop row where bandname(S2bandname) is B10
spectral_map_lut = spectral_map_lut.drop(spectral_map_lut[spectral_map_lut["bandname(S2bandname)"] == "B10"].index)

# Display the dataframe
print(spectral_map_lut.to_string(index=False))
# Out:
# bandname(S2bandname)  res(m)  wavelenth(nm)  reflectance(degree)                     description
#                   B1      60            443                0.024 Ultra Blue (Coastal and Aerosol)
#                   B2      10            490                0.028                             Blue
#                   B3      10            560                0.061                            Green
#                   B4      10            665                0.031                              Red
#                   B5      20            705                0.111 Visible and Near Infrared (VNIR)
#                   B6      20            740                0.229 Visible and Near Infrared (VNIR)
#                   B7      20            783                0.239 Visible and Near Infrared (VNIR)
#                   B8      10            842                0.241 Visible and Near Infrared (VNIR)
#                  B8A      20            865                0.242 Visible and Near Infrared (VNIR)
#                   B9      60            940                0.237       Short Wave Infrared (SWIR)
#                  B11      20           1610                0.123       Short Wave Infrared (SWIR)
#                  B12      20           2190                0.069       Short Wave Infrared (SWIR)

# %%
# At this point, a very broad assumption is necessary: We must assume that reflectance (the paper gave no unit) with Range (0-1) 
# can be mapped to the sentinel 2 bands (0-10000) by dividing those values by 10000
# This may be a very bad assumption, but it is the only one we have.

# Written by Ben Kraas
# This script takes the Sentinel 2 bands and the wheat spectral map and finds the pixels that match the spectral mapping
# for each band. It then outputs a new raster with the matching pixels.

scaling_div_val = 10000
tolerance_fraction = 0.1

for image_dict in data_dict.values():
    print(f"Processing image {image_dict['file_name']}")
    # get the bands from the dictionary
    bands = image_dict["bands"]
    band_names = image_dict["band_names"]
    meta = image_dict["meta"]
    
    # get spectral mapping list for the bands
    spectral_mapping_ls = []
    for band_index, band_name in enumerate(band_names):
        # skip if band index is higher than the number of rows in the spectral map lut
        if band_index >= len(spectral_map_lut):
            continue

        # get the row from the spectral map where the band name matches
        band_row = spectral_map_lut[spectral_map_lut["bandname(S2bandname)"] == band_name]

        # get the reflectance value from the reflectance(degree) column
        reflectance = band_row["reflectance(degree)"].values[0]

        spectral_mapping_ls.append(float(reflectance))

    print(f"  Spectral mapping list: {spectral_mapping_ls}")

    # Attempt to find pixels that are within the tolerance of the spectral mapping for each band


    # Scale the spectral mapping values to match the Sentinel 2 bands
    spectral_mapping_ls = [reflectance * scaling_div_val for reflectance in spectral_mapping_ls]
    print(f"  Scaled spectral mapping list: {spectral_mapping_ls}")

    # Iterate over each band and find pixels that match the spectral mapping
    # Initialize a list to store the indices of the pixels that match the spectral mapping
    output_raster = np.zeros(bands[0].shape, dtype=np.float64)
    print(f"  Output raster initialized with shape: {output_raster.shape}")

    # Find the matching pixels for each band
    print("  Finding matching pixels... Number of bands: ", len(bands))
    for band_index, band in enumerate(bands):
        # initialize the match raster with nan
        match_raster = np.full(band.shape, np.nan)

        # skip if band index is higher than the number of rows in the spectral map lut
        if band_index >= len(spectral_mapping_ls):
            continue

        # get the reflectance value from the spectral mapping list
        reflectance = round(spectral_mapping_ls[band_index], 3)

        # find pixels that are within the tolerance of the spectral mapping
        matching_pixels = np.abs(band - reflectance) <= (tolerance_fraction * reflectance)

        # give the match_raster the deviation from the reflectance value in percentage (0-1)
        match_raster[matching_pixels] = np.abs((band[matching_pixels] - reflectance) / reflectance) * 10

        print(f"    Match raster mean: {np.nanmean(match_raster)}, min: {np.nanmin(match_raster)}, max: {np.nanmax(match_raster)}")

        # add each match raster deviation value on top of the output raster
        output_raster += np.nan_to_num(match_raster, nan=0.0)

        # Print the number of matching pixels for each band with padding
        print(f"    Band {band_names[band_index]:<4} chosen reflectance: {reflectance:<7} matching pixels: {np.sum(matching_pixels):<7}/"
              f"{band.size:<7} ({np.sum(matching_pixels) / band.size * 100:>6.2f}%) mean deviation: {np.nanmean(match_raster):<7.3f}")
    
    print(f"  Output raster shape: {output_raster.shape}, Output raster min: {np.nanmin(output_raster)}, max: {np.nanmax(output_raster)}")

    
    # Save the output raster to a new file

    # get the metadata from the first band
    meta = image_dict["meta"]

    # update the metadata for the output raster
    meta.update({
        "dtype": "float64",
        "count": 1,
        "compress": "LZW",
        "driver": "GTiff",
        "nodata": np.nan,
    })

    # make sure the output directory exists
    Path("data/output/spectral_match").mkdir(parents=True, exist_ok=True)

    # get the output file name
    output_file_name = f"data/output/spectral_match/{image_dict['file_name']}"

    # remove the .tif extension from the file name
    output_file_name = output_file_name.replace(".tif", "_output.tif")

    # save the output raster to a new file, overwriting if it already exists
    with rasterio.open(output_file_name, "w", **meta) as dst:
        # write the pixel number raster to the output file
        dst.write(output_raster.astype("float64"), 1)
        print(f"  Saved output raster to {output_file_name}")
# Out:
# Processing image S2_2022_2_summer.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5272792886850464, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 15834  /1462284 (  1.08%) mean deviation: 0.527
#     Match raster mean: 0.5196151907001554, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 7867   /1462284 (  0.54%) mean deviation: 0.520
#     Match raster mean: 0.49213031232443166, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 120231 /1462284 (  8.22%) mean deviation: 0.492
#     Match raster mean: 0.5183649223931094, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 5654   /1462284 (  0.39%) mean deviation: 0.518
#     Match raster mean: 0.48380612111790067, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 198808 /1462284 ( 13.60%) mean deviation: 0.484
#     Match raster mean: 0.4894060471763674, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 204614 /1462284 ( 13.99%) mean deviation: 0.489
#     Match raster mean: 0.4936247892769559, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 192976 /1462284 ( 13.20%) mean deviation: 0.494
#     Match raster mean: 0.4909855926058098, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 193675 /1462284 ( 13.24%) mean deviation: 0.491
#     Match raster mean: 0.48742953716725756, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 187674 /1462284 ( 12.83%) mean deviation: 0.487
#     Match raster mean: 0.4875708782385924, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 165975 /1462284 ( 11.35%) mean deviation: 0.488
#     Match raster mean: 0.5024776786812676, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 1468   /1462284 (  0.10%) mean deviation: 0.502
#     Match raster mean: 0.5085220004343842, min: 0.0, max: 0.9989648033126296
#     Band B12  chosen reflectance: 690.0   matching pixels: 3568   /1462284 (  0.24%) mean deviation: 0.509
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.6094383094397156
#   Saved output raster to data/output/spectral_match/S2_2022_2_summer_output.tif
# Processing image S2_2021_1_spring.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5012610665984155, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 43804  /1462284 (  3.00%) mean deviation: 0.501
#     Match raster mean: 0.5056934647147338, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 45713  /1462284 (  3.13%) mean deviation: 0.506
#     Match raster mean: 0.49664056610907653, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 115554 /1462284 (  7.90%) mean deviation: 0.497
#     Match raster mean: 0.5412533404252037, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 4816   /1462284 (  0.33%) mean deviation: 0.541
#     Match raster mean: 0.5066547262703317, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 88724  /1462284 (  6.07%) mean deviation: 0.507
#     Match raster mean: 0.5088134350579806, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 31092  /1462284 (  2.13%) mean deviation: 0.509
#     Match raster mean: 0.5068659175845105, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 39494  /1462284 (  2.70%) mean deviation: 0.507
#     Match raster mean: 0.5137740813262952, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 47288  /1462284 (  3.23%) mean deviation: 0.514
#     Match raster mean: 0.5141402697259418, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 49231  /1462284 (  3.37%) mean deviation: 0.514
#     Match raster mean: 0.5109911259970701, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 54575  /1462284 (  3.73%) mean deviation: 0.511
#     Match raster mean: 0.5338672466648318, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 16462  /1462284 (  1.13%) mean deviation: 0.534
#     Match raster mean: 0.49391806222928303, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 3840   /1462284 (  0.26%) mean deviation: 0.494
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.8081950053004485
#   Saved output raster to data/output/spectral_match/S2_2021_1_spring_output.tif
# Processing image S2_2024_4_winter.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5307092440801456, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 122    /1462284 (  0.01%) mean deviation: 0.531
#     Match raster mean: 0.5109059725585149, min: 0.008928571428571428, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 118    /1462284 (  0.01%) mean deviation: 0.511
#     Match raster mean: 0.49627237413572955, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 18416  /1462284 (  1.26%) mean deviation: 0.496
#     Match raster mean: 0.5543765327296736, min: 0.08602150537634469, max: 0.9784946236559133
#     Band B4   chosen reflectance: 310.0   matching pixels: 57     /1462284 (  0.00%) mean deviation: 0.554
#     Match raster mean: 0.49718668657003795, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 46473  /1462284 (  3.18%) mean deviation: 0.497
#     Match raster mean: 0.5005770897002839, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 74269  /1462284 (  5.08%) mean deviation: 0.501
#     Match raster mean: 0.5014723979539808, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 77296  /1462284 (  5.29%) mean deviation: 0.501
#     Match raster mean: 0.49710162853799955, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 81976  /1462284 (  5.61%) mean deviation: 0.497
#     Match raster mean: 0.5013344992547709, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 84555  /1462284 (  5.78%) mean deviation: 0.501
#     Match raster mean: 0.4988576529009477, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 83190  /1462284 (  5.69%) mean deviation: 0.499
#     Match raster mean: 0.4870276384510961, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 146783 /1462284 ( 10.04%) mean deviation: 0.487
#     Match raster mean: 0.4913284886336116, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 14556  /1462284 (  1.00%) mean deviation: 0.491
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 4.751374512009475
#   Saved output raster to data/output/spectral_match/S2_2024_4_winter_output.tif
# Processing image S2_2022_3_autumn.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.4912260580629275, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 102929 /1462284 (  7.04%) mean deviation: 0.491
#     Match raster mean: 0.4931203308236757, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 99660  /1462284 (  6.82%) mean deviation: 0.493
#     Match raster mean: 0.5086415749996033, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 93289  /1462284 (  6.38%) mean deviation: 0.509
#     Match raster mean: 0.5208749343274969, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 8771   /1462284 (  0.60%) mean deviation: 0.521
#     Match raster mean: 0.5166254313377908, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 65198  /1462284 (  4.46%) mean deviation: 0.517
#     Match raster mean: 0.5113291641435143, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 23921  /1462284 (  1.64%) mean deviation: 0.511
#     Match raster mean: 0.5138354760256751, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 29460  /1462284 (  2.01%) mean deviation: 0.514
#     Match raster mean: 0.5136673194291639, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 41798  /1462284 (  2.86%) mean deviation: 0.514
#     Match raster mean: 0.511121903765233, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 44620  /1462284 (  3.05%) mean deviation: 0.511
#     Match raster mean: 0.5113108635056367, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 51536  /1462284 (  3.52%) mean deviation: 0.511
#     Match raster mean: 0.5263678196998702, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 20259  /1462284 (  1.39%) mean deviation: 0.526
#     Match raster mean: 0.5251179152536347, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 3034   /1462284 (  0.21%) mean deviation: 0.525
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 6.3191248922367755
#   Saved output raster to data/output/spectral_match/S2_2022_3_autumn_output.tif
# Processing image S2_2023_1_spring.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5929327717937802, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 2573   /1462284 (  0.18%) mean deviation: 0.593
#     Match raster mean: 0.5732225346208455, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 4532   /1462284 (  0.31%) mean deviation: 0.573
#     Match raster mean: 0.4742791107595914, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 234708 /1462284 ( 16.05%) mean deviation: 0.474
#     Match raster mean: 0.5237087288576526, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 4617   /1462284 (  0.32%) mean deviation: 0.524
#     Match raster mean: 0.5084931993199763, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 169432 /1462284 ( 11.59%) mean deviation: 0.508
#     Match raster mean: 0.5080418791371778, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 68156  /1462284 (  4.66%) mean deviation: 0.508
#     Match raster mean: 0.5028053201060506, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 79724  /1462284 (  5.45%) mean deviation: 0.503
#     Match raster mean: 0.5001418756555085, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 91277  /1462284 (  6.24%) mean deviation: 0.500
#     Match raster mean: 0.5014298634420844, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 94172  /1462284 (  6.44%) mean deviation: 0.501
#     Match raster mean: 0.502792537421835, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 97585  /1462284 (  6.67%) mean deviation: 0.503
#     Match raster mean: 0.5423494026122546, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 5245   /1462284 (  0.36%) mean deviation: 0.542
#     Match raster mean: 0.5159520765614966, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 2461   /1462284 (  0.17%) mean deviation: 0.516
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 6.329437641981398
#   Saved output raster to data/output/spectral_match/S2_2023_1_spring_output.tif
# Processing image S2_2020_1_spring.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.528820052402058, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 7436   /1462284 (  0.51%) mean deviation: 0.529
#     Match raster mean: 0.5362429350228195, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 4009   /1462284 (  0.27%) mean deviation: 0.536
#     Match raster mean: 0.4902102603478949, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 188694 /1462284 ( 12.90%) mean deviation: 0.490
#     Match raster mean: 0.4906945873944425, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 4165   /1462284 (  0.28%) mean deviation: 0.491
#     Match raster mean: 0.5104712980972356, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 105328 /1462284 (  7.20%) mean deviation: 0.510
#     Match raster mean: 0.5193497602827681, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 24226  /1462284 (  1.66%) mean deviation: 0.519
#     Match raster mean: 0.511895017781538, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 31834  /1462284 (  2.18%) mean deviation: 0.512
#     Match raster mean: 0.5074131577023294, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 41183  /1462284 (  2.82%) mean deviation: 0.507
#     Match raster mean: 0.5094031460701388, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 39635  /1462284 (  2.71%) mean deviation: 0.509
#     Match raster mean: 0.5054989457194291, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 47293  /1462284 (  3.23%) mean deviation: 0.505
#     Match raster mean: 0.5131158371854438, min: 0.0006253908692934505, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 3510   /1462284 (  0.24%) mean deviation: 0.513
#     Match raster mean: 0.5372233793809562, min: 0.001207729468599583, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 1509   /1462284 (  0.10%) mean deviation: 0.537
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.9804077581564465
#   Saved output raster to data/output/spectral_match/S2_2020_1_spring_output.tif
# Processing image S2_2024_1_spring.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5003015660355017, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 14007  /1462284 (  0.96%) mean deviation: 0.500
#     Match raster mean: 0.4899904879709678, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 10036  /1462284 (  0.69%) mean deviation: 0.490
#     Match raster mean: 0.49478401888892876, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 130151 /1462284 (  8.90%) mean deviation: 0.495
#     Match raster mean: 0.5066173011112888, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 6012   /1462284 (  0.41%) mean deviation: 0.507
#     Match raster mean: 0.48403629361469913, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 219177 /1462284 ( 14.99%) mean deviation: 0.484
#     Match raster mean: 0.5005071584604377, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 114856 /1462284 (  7.85%) mean deviation: 0.501
#     Match raster mean: 0.5018678279381605, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 123848 /1462284 (  8.47%) mean deviation: 0.502
#     Match raster mean: 0.4968937009871474, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 144580 /1462284 (  9.89%) mean deviation: 0.497
#     Match raster mean: 0.49617904581213035, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 150825 /1462284 ( 10.31%) mean deviation: 0.496
#     Match raster mean: 0.4901187675622818, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 152767 /1462284 ( 10.45%) mean deviation: 0.490
#     Match raster mean: 0.5184171525686389, min: 0.001806684733513591, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 3804   /1462284 (  0.26%) mean deviation: 0.518
#     Match raster mean: 0.4981103459512723, min: 0.0007627765064840339, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 4222   /1462284 (  0.29%) mean deviation: 0.498
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.713084126061035
#   Saved output raster to data/output/spectral_match/S2_2024_1_spring_output.tif
# Processing image S2_2023_3_autumn.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.49754065686339854, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 81726  /1462284 (  5.59%) mean deviation: 0.498
#     Match raster mean: 0.5281717436659774, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 23533  /1462284 (  1.61%) mean deviation: 0.528
#     Match raster mean: 0.49773385935500564, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 139532 /1462284 (  9.54%) mean deviation: 0.498
#     Match raster mean: 0.5127668978239142, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 3082   /1462284 (  0.21%) mean deviation: 0.513
#     Match raster mean: 0.5067666675208587, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 121990 /1462284 (  8.34%) mean deviation: 0.507
#     Match raster mean: 0.5338992837519512, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 15936  /1462284 (  1.09%) mean deviation: 0.534
#     Match raster mean: 0.521364252324583, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 27586  /1462284 (  1.89%) mean deviation: 0.521
#     Match raster mean: 0.5191453126383941, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 43128  /1462284 (  2.95%) mean deviation: 0.519
#     Match raster mean: 0.5165266022097257, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 51965  /1462284 (  3.55%) mean deviation: 0.517
#     Match raster mean: 0.5054198253140079, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 71989  /1462284 (  4.92%) mean deviation: 0.505
#     Match raster mean: 0.5233185397734461, min: 0.0011614401858301656, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 2578   /1462284 (  0.18%) mean deviation: 0.523
#     Match raster mean: 0.500679691936677, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 2039   /1462284 (  0.14%) mean deviation: 0.501
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.149835565124797
#   Saved output raster to data/output/spectral_match/S2_2023_3_autumn_output.tif
# Processing image S2_2020_3_autumn.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.49848398123688986, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 39453  /1462284 (  2.70%) mean deviation: 0.498
#     Match raster mean: 0.5083569063387117, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 10772  /1462284 (  0.74%) mean deviation: 0.508
#     Match raster mean: 0.4882374821642217, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 115814 /1462284 (  7.92%) mean deviation: 0.488
#     Match raster mean: 0.5211803466364464, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 1087   /1462284 (  0.07%) mean deviation: 0.521
#     Match raster mean: 0.4901397556666319, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 155942 /1462284 ( 10.66%) mean deviation: 0.490
#     Match raster mean: 0.5277229106418846, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 19358  /1462284 (  1.32%) mean deviation: 0.528
#     Match raster mean: 0.516912580923754, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 26550  /1462284 (  1.82%) mean deviation: 0.517
#     Match raster mean: 0.5223030556399814, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 42460  /1462284 (  2.90%) mean deviation: 0.522
#     Match raster mean: 0.5229281703811995, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 48951  /1462284 (  3.35%) mean deviation: 0.523
#     Match raster mean: 0.5121129648063746, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 67898  /1462284 (  4.64%) mean deviation: 0.512
#     Match raster mean: 0.5570202209963545, min: 0.0005420054200537076, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 3293   /1462284 (  0.23%) mean deviation: 0.557
#     Match raster mean: 0.5135487177448256, min: 0.0014492753623191702, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 1221   /1462284 (  0.08%) mean deviation: 0.514
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.565918080138578
#   Saved output raster to data/output/spectral_match/S2_2020_3_autumn_output.tif
# Processing image S2_2021_4_winter.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5070290205378258, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 5579   /1462284 (  0.38%) mean deviation: 0.507
#     Match raster mean: 0.5117160006121027, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 9091   /1462284 (  0.62%) mean deviation: 0.512
#     Match raster mean: 0.496922169245557, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 9779   /1462284 (  0.67%) mean deviation: 0.497
#     Match raster mean: 0.4973917014233215, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 6320   /1462284 (  0.43%) mean deviation: 0.497
#     Match raster mean: 0.49804589178325287, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 28187  /1462284 (  1.93%) mean deviation: 0.498
#     Match raster mean: 0.49987264534850495, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 106350 /1462284 (  7.27%) mean deviation: 0.500
#     Match raster mean: 0.4979664379648174, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 107718 /1462284 (  7.37%) mean deviation: 0.498
#     Match raster mean: 0.4938256414898917, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 110128 /1462284 (  7.53%) mean deviation: 0.494
#     Match raster mean: 0.5001431468731369, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 113897 /1462284 (  7.79%) mean deviation: 0.500
#     Match raster mean: 0.5026341473453263, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 113554 /1462284 (  7.77%) mean deviation: 0.503
#     Match raster mean: 0.5032023807722773, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 141872 /1462284 (  9.70%) mean deviation: 0.503
#     Match raster mean: 0.5070568438232637, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 24066  /1462284 (  1.65%) mean deviation: 0.507
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.60032320419222
#   Saved output raster to data/output/spectral_match/S2_2021_4_winter_output.tif
# Processing image S2_2024_3_autumn.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5182820231397083, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 40563  /1462284 (  2.77%) mean deviation: 0.518
#     Match raster mean: 0.5175203504168517, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 6306   /1462284 (  0.43%) mean deviation: 0.518
#     Match raster mean: 0.48053854898380854, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 227687 /1462284 ( 15.57%) mean deviation: 0.481
#     Match raster mean: 0.427191688578255, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 2412   /1462284 (  0.16%) mean deviation: 0.427
#     Match raster mean: 0.4897189367164155, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 214494 /1462284 ( 14.67%) mean deviation: 0.490
#     Match raster mean: 0.5275446146051851, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 6052   /1462284 (  0.41%) mean deviation: 0.528
#     Match raster mean: 0.5444884664561218, min: 0.0002092050209212632, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 9905   /1462284 (  0.68%) mean deviation: 0.544
#     Match raster mean: 0.5352978846844504, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 17740  /1462284 (  1.21%) mean deviation: 0.535
#     Match raster mean: 0.5388935420398925, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 22428  /1462284 (  1.53%) mean deviation: 0.539
#     Match raster mean: 0.5355090298692987, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 32930  /1462284 (  2.25%) mean deviation: 0.536
#     Match raster mean: 0.5137549709849406, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 2062   /1462284 (  0.14%) mean deviation: 0.514
#     Match raster mean: 0.5024570615903812, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 975    /1462284 (  0.07%) mean deviation: 0.502
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.315086707998444
#   Saved output raster to data/output/spectral_match/S2_2024_3_autumn_output.tif
# Processing image S2_2024_2_summer.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5286517422804943, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 972    /1462284 (  0.07%) mean deviation: 0.529
#     Match raster mean: 0.5255123488240899, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 1675   /1462284 (  0.11%) mean deviation: 0.526
#     Match raster mean: 0.5356596043968483, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 54145  /1462284 (  3.70%) mean deviation: 0.536
#     Match raster mean: 0.5002608355605815, min: 0.0, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 1803   /1462284 (  0.12%) mean deviation: 0.500
#     Match raster mean: 0.4771056652646027, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 165867 /1462284 ( 11.34%) mean deviation: 0.477
#     Match raster mean: 0.5042911473870766, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 133865 /1462284 (  9.15%) mean deviation: 0.504
#     Match raster mean: 0.49987800817843625, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 157241 /1462284 ( 10.75%) mean deviation: 0.500
#     Match raster mean: 0.498899219973655, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 167898 /1462284 ( 11.48%) mean deviation: 0.499
#     Match raster mean: 0.4895128228434773, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 189504 /1462284 ( 12.96%) mean deviation: 0.490
#     Match raster mean: 0.4921163680473546, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 150173 /1462284 ( 10.27%) mean deviation: 0.492
#     Match raster mean: 0.5233586914540929, min: 0.005807200929152677, max: 0.9992609016999268
#     Band B11  chosen reflectance: 1230.0  matching pixels: 1108   /1462284 (  0.08%) mean deviation: 0.523
#     Match raster mean: 0.5103793586927099, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 1639   /1462284 (  0.11%) mean deviation: 0.510
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 5.503026616797786
#   Saved output raster to data/output/spectral_match/S2_2024_2_summer_output.tif
# Processing image S2_2023_4_winter.tif
#   Spectral mapping list: [0.024, 0.028, 0.061, 0.031, 0.111, 0.229, 0.239, 0.241, 0.242, 0.237, 0.123, 0.069]
#   Scaled spectral mapping list: [240.0, 280.0, 610.0, 310.0, 1110.0, 2290.0, 2390.0, 2410.0, 2420.0, 2370.0, 1230.0, 690.0000000000001]
#   Output raster initialized with shape: (906, 1614)
#   Finding matching pixels... Number of bands:  26
#     Match raster mean: 0.5157672021511306, min: 0.0, max: 1.0
#     Band B1   chosen reflectance: 240.0   matching pixels: 3626   /1462284 (  0.25%) mean deviation: 0.516
#     Match raster mean: 0.5189755569633618, min: 0.0, max: 1.0
#     Band B2   chosen reflectance: 280.0   matching pixels: 2255   /1462284 (  0.15%) mean deviation: 0.519
#     Match raster mean: 0.5072044009857222, min: 0.0, max: 1.0
#     Band B3   chosen reflectance: 610.0   matching pixels: 34878  /1462284 (  2.39%) mean deviation: 0.507
#     Match raster mean: 0.5410906298003073, min: 0.03225806451612903, max: 1.0
#     Band B4   chosen reflectance: 310.0   matching pixels: 49     /1462284 (  0.00%) mean deviation: 0.541
#     Match raster mean: 0.4916965698005207, min: 0.0, max: 1.0
#     Band B5   chosen reflectance: 1110.0  matching pixels: 109417 /1462284 (  7.48%) mean deviation: 0.492
#     Match raster mean: 0.5006961856307426, min: 0.0, max: 1.0
#     Band B6   chosen reflectance: 2290.0  matching pixels: 59120  /1462284 (  4.04%) mean deviation: 0.501
#     Match raster mean: 0.505370467290145, min: 0.0, max: 1.0
#     Band B7   chosen reflectance: 2390.0  matching pixels: 56950  /1462284 (  3.89%) mean deviation: 0.505
#     Match raster mean: 0.5011886276222538, min: 0.0, max: 1.0
#     Band B8   chosen reflectance: 2410.0  matching pixels: 79268  /1462284 (  5.42%) mean deviation: 0.501
#     Match raster mean: 0.5025769348392447, min: 0.0, max: 1.0
#     Band B8A  chosen reflectance: 2420.0  matching pixels: 71033  /1462284 (  4.86%) mean deviation: 0.503
#     Match raster mean: 0.4987579164156499, min: 0.0, max: 1.0
#     Band B9   chosen reflectance: 2370.0  matching pixels: 72573  /1462284 (  4.96%) mean deviation: 0.499
#     Match raster mean: 0.4875977409000045, min: 0.0, max: 1.0
#     Band B11  chosen reflectance: 1230.0  matching pixels: 19997  /1462284 (  1.37%) mean deviation: 0.488
#     Match raster mean: 0.5242290633012072, min: 0.0, max: 1.0
#     Band B12  chosen reflectance: 690.0   matching pixels: 951    /1462284 (  0.07%) mean deviation: 0.524
#   Output raster shape: (906, 1614), Output raster min: 0.0, max: 4.623147639706582
#   Saved output raster to data/output/spectral_match/S2_2023_4_winter_output.tif
